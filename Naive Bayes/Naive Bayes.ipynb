# %%
import pandas as pd
from sklearn.datasets import load_wine

# %%
wine = load_wine()
dir(wine)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
df = pd.DataFrame(wine.data,wine.target,columns = wine.feature_names)
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0    14.23        1.71  2.43               15.6      127.0           2.80  \
# 0    13.20        1.78  2.14               11.2      100.0           2.65
# 0    13.16        2.36  2.67               18.6      101.0           2.80
# 0    14.37        1.95  2.50               16.8      113.0           3.85
# 0    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0        3.06                  0.28             2.29             5.64  1.04  \
# 0        2.76                  0.26             1.28             4.38  1.05
# 0        3.24                  0.30             2.81             5.68  1.03
# 0        3.49                  0.24             2.18             7.80  0.86
# 0        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 0                          3.40   1050.0
# 0                          3.17   1185.0
# 0                          3.45   1480.0
# 0                          2.93    735.0

# %%
df['target'] = wine.target

# %%
df[50:70]
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0    13.05        1.73  2.04               12.4       92.0           2.72  \
# 0    13.83        1.65  2.60               17.2       94.0           2.45
# 0    13.82        1.75  2.42               14.0      111.0           3.88
# 0    13.77        1.90  2.68               17.1      115.0           3.00
# 0    13.74        1.67  2.25               16.4      118.0           2.60
# 0    13.56        1.73  2.46               20.5      116.0           2.96
# 0    14.22        1.70  2.30               16.3      118.0           3.20
# 0    13.29        1.97  2.68               16.8      102.0           3.00
# 0    13.72        1.43  2.50               16.7      108.0           3.40
# 1    12.37        0.94  1.36               10.6       88.0           1.98
# 1    12.33        1.10  2.28               16.0      101.0           2.05
# 1    12.64        1.36  2.02               16.8      100.0           2.02
# 1    13.67        1.25  1.92               18.0       94.0           2.10
# 1    12.37        1.13  2.16               19.0       87.0           3.50
# 1    12.17        1.45  2.53               19.0      104.0           1.89
# 1    12.37        1.21  2.56               18.1       98.0           2.42
# 1    13.11        1.01  1.70               15.0       78.0           2.98
# 1    12.37        1.17  1.92               19.6       78.0           2.11
# 1    13.34        0.94  2.36               17.0      110.0           2.53
# 1    12.21        1.19  1.75               16.8      151.0           1.85
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0        3.27                  0.17             2.91             7.20  1.12  \
# 0        2.99                  0.22             2.29             5.60  1.24
# 0        3.74                  0.32             1.87             7.05  1.01
# 0        2.79                  0.39             1.68             6.30  1.13
# 0        2.90                  0.21             1.62             5.85  0.92
# 0        2.78                  0.20             2.45             6.25  0.98
# 0        3.00                  0.26             2.03             6.38  0.94
# 0        3.23                  0.31             1.66             6.00  1.07
# 0        3.67                  0.19             2.04             6.80  0.89
# 1        0.57                  0.28             0.42             1.95  1.05
# 1        1.09                  0.63             0.41             3.27  1.25
# 1        1.41                  0.53             0.62             5.75  0.98
# 1        1.79                  0.32             0.73             3.80  1.23
# 1        3.10                  0.19             1.87             4.45  1.22
# 1        1.75                  0.45             1.03             2.95  1.45
# 1        2.65                  0.37             2.08             4.60  1.19
# 1        3.18                  0.26             2.28             5.30  1.12
# 1        2.00                  0.27             1.04             4.68  1.12
# 1        1.30                  0.55             0.42             3.17  1.02
# 1        1.28                  0.14             2.50             2.85  1.28
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          2.91   1150.0       0
# 0                          3.37   1265.0       0
# 0                          3.26   1190.0       0
# 0                          2.93   1375.0       0
# 0                          3.20   1060.0       0
# 0                          3.03   1120.0       0
# 0                          3.31    970.0       0
# 0                          2.84   1270.0       0
# 0                          2.87   1285.0       0
# 1                          1.82    520.0       1
# 1                          1.67    680.0       1
# 1                          1.59    450.0       1
# 1                          2.46    630.0       1
# 1                          2.87    420.0       1
# 1                          2.23    355.0       1
# 1                          2.30    678.0       1
# 1                          3.18    502.0       1
# 1                          3.48    510.0       1
# 1                          1.93    750.0       1
# 1                          3.07    718.0       1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(wine.data,wine.target,test_size=0.2,random_state = 100)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
gb = GaussianNB()
gb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
gb.score(X_test,y_test)
# Out:
# 1.0

# %%
mb = MultinomialNB()
mb.fit(X_train,y_train)
mb.score(X_test,y_test)
# Out:
# 0.8333333333333334
